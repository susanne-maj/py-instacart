# %% [markdown]
# # 4.6 COMBINING DATA

# %% [markdown]
# ## Contents:
# 1. Define libraries and import data
# 2. Merge data sets
# 3. Export data

# %% [markdown]
# ### 1. Import libraries and import data

# %%
import pandas as pd
import numpy as np
import os

# %%
# define path
path = r'C:\Users\susan\Documents\data analytics\Instacart Basket Analysis\02 Data\Prepared data'

# %%
path
# Out:
# 'C:\\Users\\susan\\Documents\\data analytics\\Instacart Basket Analysis\\02 Data\\Prepared data'

# %%
# import df_ords_prior (original) and df_ords
df_ords_prior = pd.read_csv(os.path.join(path, 'orders_products_prior.csv'))
df_ords = pd.read_csv(os.path.join(path, 'orders_checked.csv'))

# %%
df_ords.shape
# Out:
# (11, 7)

# %%
# Check dimensions
print(df_ords_prior.shape)
# Out:
# (32434489, 4)

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Check dimensions
print(df_ords.shape)
# Out:
# (11, 7)

# %%
# Check the output
df_ords.head()
# Out:
#    order_id  user_id validation  order_number  orders_day_of_week  \
# 0   2539329        1      prior             1                   2
# 1   2398795        1      prior             2                   3
# 2    473747        1      prior             3                   3
# 3   2254736        1      prior             4                   4
# 4    431534        1      prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# ## 2. Merge data sets

# %%
# Merge df_ords_prior with df_ords (shows observations in both dataframes, inner-join)
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head(20)
# Out:
#     order_id  user_id validation  order_number  orders_day_of_week  \
# 0    2539329        1      prior             1                   2
# 1    2539329        1      prior             1                   2
# 2    2539329        1      prior             1                   2
# 3    2539329        1      prior             1                   2
# 4    2539329        1      prior             1                   2
# 5    2398795        1      prior             2                   3
# 6    2398795        1      prior             2                   3
# 7    2398795        1      prior             2                   3
# 8    2398795        1      prior             2                   3
# 9    2398795        1      prior             2                   3
# 10   2398795        1      prior             2                   3
# 11    473747        1      prior             3                   3
# 12    473747        1      prior             3                   3
# ...

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_merged_large.shape
# Out:
# (59, 11)

# %%
# Sum up values in the merge column
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          59
# left_only      0
# right_only     0
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Export data

# %%
# Export data to .pickle -- df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))
df_merged_large.to_pickle(os.path.join(path, 'orders_products_combined.pkl'))
