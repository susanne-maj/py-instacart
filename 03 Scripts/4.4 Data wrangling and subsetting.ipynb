# %%
# 1. for following the lesson. 2. for exercise section.
# 1.1 Import and check file
# 1.2. Drop and rename orders and columns
# 1.3. Change data type
# 1.4. Switch columns and add indexes
# 1.5. Run basic stats
# 2. Exercise section. Ran all above according to exercise.

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# define path
path = r'C:\Users\Administrator\Documents\data analytics\Instacart Basket Analysis\02 Data\Original Data'

# %%
# import orders
df_orders = pd.read_csv(os.path.join(path, 'orders.csv'), index_col=False)

# %%
# import products
df_products = pd.read_csv(os.path.join(path, 'products.csv'), index_col=False)

# %%
df_orders.info
# Out:
# <bound method DataFrame.info of          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# drop orders and rename file with dropped orders, create a new dataframe df_orders_dropped
df_orders_dropped = df_orders.drop(columns = ['eval_set'])
df_orders_dropped.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Save the column first
col = df_orders['eval_set'].copy()

# %%
# Dropping the column from the source data frame
df_orders.drop(columns = ['eval_set'],inplace=True)

# %%
df_orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Getting the column back to the source data frame
df_orders['eval_set'] = col
df_orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order eval_set
# 0                     NaN    prior
# 1                    15.0    prior
# 2                    21.0    prior
# 3                    29.0    prior
# 4                    28.0    prior

# %%
# use value_counts() function on the "days_since_prior_order" columns in your df_orders df
df_orders['days_since_prior_order'].value_counts(dropna=False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
# Rename column and display it
df_orders.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)
df_orders.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order eval_set
# 0                     NaN    prior
# 1                    15.0    prior
# 2                    21.0    prior
# 3                    29.0    prior
# 4                    28.0    prior

# %%
# change the data type of the "order_id" column from a number to a string so that the describe function ignores it.
df_orders['order_id'] = df_orders['order_id'].astype('str')

# %%
df_orders['order_id'].dtype
# Out:
# dtype('O')

# %%
# import departments file
df_dep = pd.read_csv(os.path.join(path, 'departments.csv'), index_col=False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# switch rows and columns
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# create a new df with the switched columns
df_dep_t = df_dep.T
df_dep_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
# Add an index to the dataframe (to get rid of row 0 eventually)
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Remove the first row in the df_dep_t_new file
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new.reset_index()
# Out:
#    index                0
# 0      1           frozen
# 1      2            other
# 2      3           bakery
# 3      4          produce
# 4      5          alcohol
# 5      6    international
# 6      7        beverages
# 7      8             pets
# 8      9  dry goods pasta
# 9     10             bulk
# 10    11    personal care
# 11    12     meat seafood
# 12    13           pantry
# 13    14        breakfast
# 14    15     canned goods
# 15    16       dairy eggs
# 16    17        household
# 17    18           babies
# 18    19           snacks
# 19    20             deli
# 20    21          missing

# %%
# Set the header row as the df_header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new.head()
# Out:
# department_id department
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol

# %%
# turn dataframe "df_dep_t_new" into a dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
# call the data dictionary
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# find out what the department_id 19 stands for
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
# create a subset of df_products that only contains the snacks dep.
df_snacks =  df_products[df_products['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# EXERCISE PROCEDURES BELOW

# %%
# (2) change the data type of the "user_id" column from a number to a string so that the describe function ignores it.
df_orders['order_id'] = df_orders['order_id'].astype('str')

# %%
df_orders.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2398795        1             2                   3                  7
# 2   473747        1             3                   3                 12
# 3  2254736        1             4                   4                  7
# 4   431534        1             5                   4                 15
#
#    days_since_prior_order eval_set
# 0                     NaN    prior
# 1                    15.0    prior
# 2                    21.0    prior
# 3                    29.0    prior
# 4                    28.0    prior

# %%
# (3) Rename column and display it
df_orders.rename(columns = {'eval_set' : 'validation'}, inplace = True)
df_orders.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2398795        1             2                   3                  7
# 2   473747        1             3                   3                 12
# 3  2254736        1             4                   4                  7
# 4   431534        1             5                   4                 15
#
#    days_since_prior_order validation
# 0                     NaN      prior
# 1                    15.0      prior
# 2                    21.0      prior
# 3                    29.0      prior
# 4                    28.0      prior

# %%
# (4) Find the frequency of order_hour_of_day (busiest hour)
df_orders['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %%
# (5) # turn dataframe "df_orders" into a dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
# (5) call the data dictionary
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# (5) find out what 4 stands for
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# (6) create a subset of df_products that only contains the breakfast item sales
df_breakfast =  df_products[df_products['department_id']==14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
# (7) create a subset of df_products contains alc, deli, bev and meat/seafood.
df_dinner =  df_products[df_products['department_id'].isin([5,7,12,20])]

# %%
df_dinner.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 16          17                               Rendered Duck Fat        35
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 16             12    17.1

# %%
# (8) How many rows does df_dinner have?
df_dinner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7650 entries, 2 to 49688
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     7650 non-null   int64
#  1   product_name   7647 non-null   object
#  2   aisle_id       7650 non-null   int64
#  3   department_id  7650 non-null   int64
#  4   prices         7650 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 358.6+ KB

# %%
# (9) Information about user_id 1
df_orders_1 =  df_orders[df_orders['user_id']==1]

# %%
df_orders_1.head(10)
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2398795        1             2                   3                  7
# 2   473747        1             3                   3                 12
# 3  2254736        1             4                   4                  7
# 4   431534        1             5                   4                 15
# 5  3367565        1             6                   2                  7
# 6   550135        1             7                   1                  9
# 7  3108588        1             8                   1                 14
# 8  2295261        1             9                   1                 16
# 9  2550362        1            10                   4                  8
#
#    days_since_prior_order validation
# 0                     NaN      prior
# 1                    15.0      prior
# 2                    21.0      prior
# ...

# %%
# provide basic stats
df_orders_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                11 non-null     object
#  1   user_id                 11 non-null     int64
#  2   order_number            11 non-null     int64
#  3   orders_day_of_week      11 non-null     int64
#  4   order_hour_of_day       11 non-null     int64
#  5   days_since_prior_order  10 non-null     float64
#  6   validation              11 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 704.0+ bytes

# %%
# (12) I defined the path again since the preivous went to Original data
from pathlib import Path
path = Path("C:/Users/Administrator/Documents/data analytics/Instacart Basket Analysis/02 Data/Prepared Data")

# %%
print(path)
# Out:
# C:\Users\Administrator\Documents\data analytics\Instacart Basket Analysis\02 Data\Prepared Data

# %%
df_orders.shape
# Out:
# (3421083, 7)

# %%
# (12) export the df_orders to orders_wrangled
df_orders.to_csv(path/'orders_wrangled.csv', index=False)

# %%
df_orders.shape
# Out:
# (3421083, 7)

# %%
df_dep_t_new.shape
# Out:
# (21, 1)

# %%
# (13) export the df_dep_t_new to departments_wrangled
df_dep_t_new.to_csv(path/'departments_wrangled.csv', index=False)
